# %%
#Task1 
import mysql.connector as con
import logging as log
log.basicConfig(filename='info.log',level=log.INFO,  format="%(asctime)s %(levelname)s %(name)s  %(message)s " )

try:
    mydb = con.connect(host='localhost', user='root', passwd = 'Golu12#$')
    log.info("Connection is established")
    cursor =mydb.cursor()
    '''Create a data base and table '''
    database = 'create database if not exists Task'
    atr_tb = '''create table if not exists Task.Attribute_DataSet (Dress_ID int,Style varchar(15),Price varchar(15),Rating float,
        Size varchar(15), Season varchar(15), NeckLine varchar(15), SleeveLength varchar(15), waiseline	varchar(15),Material varchar(15),
        FabricType	varchar(15), Decoration varchar(15), Pattern_Type varchar(15), Recommendation int)'''
    dres_tb = """create table if not exists Task.Dress_sales (Dress_ID int, `29/8/2013` int,
        `31/8/2013` int,`09-02-2013` int,`09-04-2013` int,`09-06-2013` int,
        `09-08-2013` int,`09-10-2013` int,`09-12-2013` int,`14/9/2013` int,`16/9/2013` int,
        `18/9/2013` int,`20/9/2013` int,`22/9/2013` int,`24/9/2013` int,`26/9/2013` int,
        `28/9/2013` int,`30/9/2013` int,`10-02-2013` int,`10-04-2013` int,`10-06-2013` int,
        `10-08-2010` int,`10-10-2013` int,`10-12-2013` int)"""
    try:
        cursor.execute(database)
        log.info("data base is created ")
        cursor.execute(atr_tb)
        log.info("Table Attribute Dataset is created ")
        cursor.execute(dres_tb)
        log.info("Table Dress Sales Dataset is created ")
    except Exception as e:
        log.error("Data base or table is not created is already created")
        print(e)
except con.Error as e1:
    log.error("somethening went wrong")
    print("Something went wrong: {}".format(e1))
finally:
    mydb.close()

# %%
#Task2 Loaded data thru Table data Import Wizard 
select * from attribute_dataset
#Varified data is comming 
select * from dress_sales

# %%
import pandas as pd
import mysql.connector as con
mydb = con.connect(host='localhost', user='root', passwd = 'Golu12#$')
print(mydb)
q1 =pd.read_sql('''select * from task.attribute_dataset''', mydb)
q2 =pd.read_sql('''select * from task.dress_sales''',mydb)

df1 =  pd.DataFrame(q1 , columns =["dress_id", "Style", "Price", "Rating", "Size", "Season", 
                                   "NeckLine", "SleeveLength", "waiseline", "Material", "FabricType",
                                   "Decoration", "Pattern_Type", "Recommendation"])
print(df1)

df2 =  pd.DataFrame(q2 , columns =["Dress_ID","29/8/2013","31/8/2013","09-02-2013","09-04-2013",
                                   "09-06-2013","09-08-2013","09-10-2013","09-12-2013","14/9/2013",
                                   "16/9/2013","18/9/2013","20/9/2013","22/9/2013","24/9/2013","26/9/2013",
                                   "28/9/2013","30/9/2013","10-02-2013","10-04-2013","10-06-2013","10-08-2010",
                                   "10-10-2013","10-12-2013",])
print(df2)
# Out:
# ...
#      dress_id    Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 0         NaN     Sexy      Low     4.6     M  Summer     o-neck    sleevless
# 1         NaN   Casual      Low     0.0     L  Summer     o-neck        Petal
# 2         NaN  vintage     High     0.0     L  Automn     o-neck         full
# 3         NaN    Brief  Average     4.6     L  Spring     o-neck         full
# 4         NaN     cute      Low     4.5     M  Summer     o-neck    butterfly
# ..        ...      ...      ...     ...   ...     ...        ...          ...
# 495       NaN   Casual      Low     4.7     M  Spring     o-neck         full
# 496       NaN     Sexy      Low     4.3  free  Summer     o-neck         full
# 497       NaN   Casual  Average     4.7     M  Summer     v-neck         full
# 498       NaN   Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499       NaN   Casual      Low     4.4  free  Summer     v-neck        short
#
# ...

# %%
#4. Convert attribute dataset in json format 

jason_as = q1.to_dict(orient="records")
jason_ds = q2.to_dict(orient= "records")

# %%
jason_ds
# Out:
# [{'Dress_ID': 1006032852,
#   '29/8/2013': 2114,
#   '31/8/2013': 2274,
#   '09-02-2013': 2491,
#   '09-04-2013': 2660,
#   '09-06-2013': 2727,
#   '09-08-2013': 2887,
#   '09-10-2013': 2930,
#   '09-12-2013': 3119,
#   '14/9/2013': 3204,
#   '16/9/2013': 3277,
#   '18/9/2013': 3321,
#   '20/9/2013': 3386,
#   '22/9/2013': 3479,
#   '24/9/2013': 3554,
#   '26/9/2013': 3624,
#   '28/9/2013': 3706,
#   '30/9/2013': 3746,
#   '10-02-2013': 3795,
#   '10-04-2013': 3832,
#   '10-06-2013': 3897,
#   '10-08-2010': 3923,
#   '10-10-2013': 3985,
#   '10-12-2013': 4048},
#  {'Dress_ID': 1212192089,
#   '29/8/2013': 151,
#   '31/8/2013': 275,
#   '09-02-2013': 570,
#   '09-04-2013': 750,
#   '09-06-2013': 813,
#   '09-08-2013': 1066,
#   '09-10-2013': 1164,
#   '09-12-2013': 1558,
#   '14/9/2013': 1756,
#   '16/9/2013': 1878,
#   '18/9/2013': 1985,
#   '20/9/2013': 2106,
#   '22/9/2013': 2454,
#   '24/9/2013': 2710,
#   '26/9/2013': 2942,
#   '28/9/2013': 3258,
#   '30/9/2013': 3354,
# ...

# %%
#5. Store this dataset into mongodb
import pandas as pd
import mysql.connector as con
import pymongo

mydb = con.connect(host='localhost', user='root', passwd = 'Golu12#$')

client = pymongo.MongoClient("mongodb+srv://Ballu:golu12@ballu.3rwkydg.mongodb.net/?retryWrites=true&w=majority")
db = client.test

q1 =pd.read_sql('''select * from task.attribute_dataset''', mydb)
q2 =pd.read_sql('''select * from task.dress_sales''',mydb)

jason_as = q1.to_dict(orient="records")
jason_ds = q2.to_dict(orient= "records")

database = client['task1']
collection = database["attribute1"]
collection1 = database["dress1"]
collection.insert_many(jason_as)
collection1.insert_many(jason_ds)

# %%
#Taks6 in sql task try to perform left join operation with attrubute dataset and dress dataset on column Dress_ID
import mysql.connector as con

mydb =con.connect(host = 'localhost',user='root', passwd = 'Golu12#$')
cursor =mydb.cursor()
use = 'use task'
cursor.execute(use)
leftjoin = """SELECT * FROM  attribute_dataset LEFT JOIN  dress_sales
ON attribute_dataset.Dress_ID = dress_sales.Dress_ID;"""
cursor.execute(leftjoin)
#for i in cursor.fetchall():
#     print(i)

# %%
#Taks7  Write a sql query to find out how many unique dress that we have based on dress id 
#8 Try to find out how mnay dress is having recommendation 0
import mysql.connector as con

mydb =con.connect(host = 'localhost',user='root', passwd = 'Golu12#$')
cursor =mydb.cursor()
use = 'use task'
cursor.execute(use)
uniq_dress = "select count(distinct dress_ID) from dress_sales"
cursor.execute(uniq_dress)
unircd = cursor.fetchall()
print(unircd)
#8
recomm = "select count(*) from attribute_dataset where recommendation = 0"
cursor.execute(recomm)
reco = cursor.fetchall()
print(reco)
# Out:
# [(475,)]
# [(290,)]
